# %%
import pandas as pd
from pymongo import MongoClient
from kmodes import kmodes
import numpy as np
from sklearn.metrics import pairwise_distances, silhouette_samples
from sklearn import metrics
# %pylab inline
# %matplotlib notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
client = MongoClient()
db = client.bgg
df = pd.DataFrame(list(db.game_stats.find()))

# %%
column_lst = list(df.columns.values)
# print(column_lst)
mechanics = [m for m in column_lst if 'mechanic' in m and m != 'mechanics']
indexed_df = df.set_index(['game'])
df_mechs = indexed_df[mechanics]
for col in mechanics:
    df_mechs[col] = df_mechs[col] == True
# Out:
# /Users/micahshanks/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_mechs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, pandemic-legacy-season-1 to pax-pamir
# Data columns (total 51 columns):
# Acting_mechanic                           1000 non-null bool
# Action / Movement Programming_mechanic    1000 non-null bool
# Action Point Allowance System_mechanic    1000 non-null bool
# Area Control / Area Influence_mechanic    1000 non-null bool
# Area Enclosure_mechanic                   1000 non-null bool
# Area Movement_mechanic                    1000 non-null bool
# Area-Impulse_mechanic                     1000 non-null bool
# Auction/Bidding_mechanic                  1000 non-null bool
# Betting/Wagering_mechanic                 1000 non-null bool
# Campaign / Battle Card Driven_mechanic    1000 non-null bool
# Card Drafting_mechanic                    1000 non-null bool
# Chit-Pull System_mechanic                 1000 non-null bool
# Co-operative Play_mechanic                1000 non-null bool
# ...

# %%
# mechs_x = pd.DataFrame.as_matrix(df_mechs)
# y = df_mechs.index.values

# kmodes_huang = kmodes.KModes(n_clusters=10, init='Huang', verbose=1)
# kmodes_huang.fit(mechs_x)

# # Print cluster centroids of the trained model.
# print('k-modes (Huang) centroids:')
# print(kmodes_huang.cluster_centroids_)
# # Print training statistics
# print('Final training cost: {}'.format(kmodes_huang.cost_))
# print('Training iterations: {}'.format(kmodes_huang.n_iter_))

# %%
mechs_x = pd.DataFrame.as_matrix(df_mechs)
y = df_mechs.index.values

kmodes_cao = kmodes.KModes(n_clusters=22, init='Cao', verbose=1)
kmodes_cao.fit(mechs_x)

# Print cluster centroids of the trained model.
print('k-modes (Cao) centroids:')
print(kmodes_cao.cluster_centroids_)
# Print training statistics
print('Final training cost: {}'.format(kmodes_cao.cost_))
print('Training iterations: {}'.format(kmodes_cao.n_iter_))
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 337, cost: 2680.0
# Run 1, iteration: 2/100, moves: 58, cost: 2675.0
# Run 1, iteration: 3/100, moves: 6, cost: 2675.0
# k-modes (Cao) centroids:
# [[False False False ..., False False False]
#  [False False  True ...,  True  True  True]
#  [False False False ...,  True False False]
#  ...,
#  [False False False ..., False False False]
#  [False False  True ..., False False False]
#  [False False False ...,  True False False]]
# Final training cost: 2675.0
# Training iterations: 3

# %%
# df_mechs['huang_labels'] = kmodes_huang.labels_
# cols = df_mechs.columns.tolist()
# cols = cols[-1:] + cols[:-1]
# df_mechs = df_mechs[cols]
# df_mechs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, pandemic-legacy-season-1 to pax-pamir
# Data columns (total 52 columns):
# huang_labels                              1000 non-null uint8
# Acting_mechanic                           1000 non-null bool
# Action / Movement Programming_mechanic    1000 non-null bool
# Action Point Allowance System_mechanic    1000 non-null bool
# Area Control / Area Influence_mechanic    1000 non-null bool
# Area Enclosure_mechanic                   1000 non-null bool
# Area Movement_mechanic                    1000 non-null bool
# Area-Impulse_mechanic                     1000 non-null bool
# Auction/Bidding_mechanic                  1000 non-null bool
# Betting/Wagering_mechanic                 1000 non-null bool
# Campaign / Battle Card Driven_mechanic    1000 non-null bool
# Card Drafting_mechanic                    1000 non-null bool
# Chit-Pull System_mechanic                 1000 non-null bool
# ...

# %%
# dfmechs_clusters

# %%
df_cat = pd.DataFrame()
df_cat["games"] = df_mechs.index.values
df_cat['cao_labels'] = kmodes_cao.labels_
df_cat.loc[df_cat['cao_labels'] == 17]
# Out:
#                              games  cao_labels
# 0         pandemic-legacy-season-1          17
# 37              voyages-marco-polo          17
# 39                 eldritch-horror          17
# 60                        pandemic          17
# 131                   here-i-stand          17
# 156  battlecon-devastation-indines          17
# 187                pandemic-iberia          17
# 196                  arkham-horror          17
# 231                  pandemic-cure          17
# 262      labyrinth-war-terror-2001          17
# 265           tales-arabian-nights          17
# 284   freedom-underground-railroad          17
# 306                defenders-realm          17
# 358         pandemic-reign-cthulhu          17
# 495          battlecon-war-indines          17
# 616                  julius-caesar          17
# 669                  high-frontier          17
# 690                dungeon-fighter          17
# 717                     sword-rome          17
# ...

# %%
df_cat.groupby(df_cat.cao_labels).count()
# Out:
#             games
# cao_labels
# 0             561
# 1               1
# 2              30
# 3               2
# 4               1
# 5              44
# 6              30
# 7              14
# 8              12
# 9              26
# 10              8
# 11              4
# 12              1
# 13             41
# 14             15
# 15              1
# 16              3
# 17             21
# 18              8
# 19            144
# 20             18
# 21             15

# %%
# %matplotlib notebook

from __future__ import print_function

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

print(__doc__)

X = pd.DataFrame.as_matrix(df_mechs)
y = df_mechs.index.values

range_n_clusters = [22]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(8,6)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    
#     clusterer = KMeans(n_clusters=n_clusters, random_state=10)
#     cluster_labels = clusterer.fit_predict(X)

    clusterer = kmodes.KModes(n_clusters=n_clusters, init='Cao')
    current_model = clusterer.fit(X)
    cluster_labels = current_model.labels_
    
    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = metrics.silhouette_score(X, cluster_labels, metric='hamming')
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors)

    # Labeling the clusters
#     centers = clusterer.cluster_centers_
    centers = kmodes_cao.cluster_centroids_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1],
                marker='o', c="white", alpha=1, s=200)

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=50)

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for Kmodes clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
# Out:
# Plotting functions for silhouette analysis.
# Author: Federico Tomasi
# Copyright (c) 2016, Federico Tomasi.
# Licensed under the FreeBSD license (see LICENSE.txt).
# <img src="data:image/png;base64,..." width="800">
# For n_clusters = 2 The average silhouette_score is : 0.452726431564
# <img src="data:image/png;base64,..." width="800">
# For n_clusters = 10 The average silhouette_score is : 0.152126800485
# <img src="data:image/png;base64,..." width="800">
# For n_clusters = 20 The average silhouette_score is : 0.190556956838
# <img src="data:image/png;base64,..." width="800">
# For n_clusters = 30 The average silhouette_score is : 0.209456399837

# %%
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics.pairwise import linear_kernel

distance_matrix = (1 - pairwise_distances(df_mechs, metric = "hamming"))

distance_matrix[0].argsort()[:-10:-1]
df_mechs.index.values[[  0,  60, 358, 187, 306, 862, 337, 231, 221]]
df_mechs.iloc[[  0,  60, 358, 187, 306, 862, 337, 231, 221]]
# Out:
#                          Acting_mechanic  \
# game
# pandemic-legacy-season-1           False
# pandemic                           False
# pandemic-reign-cthulhu             False
# pandemic-iberia                    False
# defenders-realm                    False
# onirim                             False
# bohnanza                           False
# pandemic-cure                      False
# sentinels-multiverse               False
#
#                          Action / Movement Programming_mechanic  \
# game
# pandemic-legacy-season-1                                  False
# pandemic                                                  False
# pandemic-reign-cthulhu                                    False
# pandemic-iberia                                           False
# defenders-realm                                           False
# onirim                                                    False
# bohnanza                                                  False
# ...

# %%
np.shape(distance_matrix)
labels = kmodes_huang.labels_
score = metrics.silhouette_score(mechs_x, labels, metric='hamming')
print(score)
# samples = silhouette_samples(x, labels)
# dm = pairwise_distances(x, metric='jaccard')
# Out:
# 0.120158827208

# %%
from sklearn.metrics import silhouette_score

def get_silhouette_score(nclust):
    clusterer = kmodes.KModes(n_clusters=nclust, init='Cao')
    current_model = clusterer.fit(X)
    cluster_labels = current_model.labels_
    silhouette_avg = metrics.silhouette_score(X, cluster_labels, metric='hamming')
    return silhouette_avg

sil_scores = [get_silhouette_score(i) for i in range(2,30)]
plt.plot(range(2,30), sil_scores)
plt.xlabel('K')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs K')
# Out:
# <img src="data:image/png;base64,..." width="800">
